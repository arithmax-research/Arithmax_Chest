# %%
from achest import MarketDataClient
with MarketDataClient() as client:
    btc = client.get(["ES.FUT"], "2025-01-01", "2025-01-31")
    print(btc.head())
# Out:
#                   timestamp   symbol provider            open            high  \
# 0  2025-01-01T00:00:00.000Z  BTCUSDT  binance  93500.00000000  95073.76000000
# 1  2025-01-02T00:00:00.000Z  BTCUSDT  binance  94650.20000000  97777.00000000
# 2  2025-01-03T00:00:00.000Z  BTCUSDT  binance  96992.78000000  98897.97000000
# 3  2025-01-04T00:00:00.000Z  BTCUSDT  binance  98186.71000000  98700.00000000
# 4  2025-01-05T00:00:00.000Z  BTCUSDT  binance  98325.25000000  98777.00000000
#
#               low           close       volume
# 0  92990.95000000  94701.87000000  18.38268000
# 1  94394.34000000  96856.15000000  16.19636000
# 2  96181.90000000  98186.71000000  14.51609000
# 3  97556.80000000  98337.49000000   6.24329000
# 4  97331.67000000  98300.03000000   7.97340000
