# %%
from achest import MarketDataClient
with MarketDataClient() as client:
    data = client.download(
        ["TRXUSDT"],
        "2026-01-01",        # start (Sunday — won't matter)
        "2026-09-05",        # end = day AFTER last trading day you want
        "daily",
        format="lean",
        provider="binance"
    )

# %%
#data.head(5)
