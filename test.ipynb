# %%
from achest import MarketDataClient
with MarketDataClient() as client:
    data = client.get(
        ["TRXUSDT"],          # list of ticker strings
        "2026-08-30",            # start date — see date formats below
        "2026-08-31",              # end date — see date formats below
        "second",
        "binance"      # bar size — see resolutions below
    )
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# Cell In[4], line 3
#       1 from achest import MarketDataClient
#       2 with MarketDataClient() as client:
# ----> 3     data = client.get(
#       4         ["TRXUSDT"],          # list of ticker strings
#       5         "2026-08-30",            # start date — see date formats below
#       6         "2026-08-31",              # end date — see date formats below
#       7         "second",
#       8         "binance"      # bar size — see resolutions below
#       9     )
#
# File ~/codechest/Arithmax_Chest/achest/client.py:130, in MarketDataClient.get(self, symbols, start, end, resolution, provider, format)
#     121 body = {
#     122     "symbols": list(symbols),
#     123     "start": str(start),
#    (...)
#     127     "format": format,
#     128 }
#     129 response = self._request("post", "/v1/data", json=body)
# --> 130 response.raise_for_status()
#     132 if format == "lean":
#     133     # Server returns a zip-of-zips. Extract inner zips and read CSVs.
#     134     return _read_lean_zip(response.content)
#
# File ~/anaconda3/envs/research_env/lib/python3.10/site-packages/httpx/_models.py:829, in Response.raise_for_status(self)
#     827 error_type = error_types.get(status_class, "Invalid status code")
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '422 Unprocessable Entity' for url 'https://achestv2.misango.me/v1/data'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/422

# %%
data.head(5)
# Out:
#                   timestamp   symbol provider        open        high  \
# 0  2026-08-30T00:00:00.000Z  TRXUSDT  binance  0.34120000  0.34120000
# 1  2026-08-30T00:01:00.000Z  TRXUSDT  binance  0.34120000  0.34120000
# 2  2026-08-30T00:02:00.000Z  TRXUSDT  binance  0.34120000  0.34120000
# 3  2026-08-30T00:03:00.000Z  TRXUSDT  binance  0.34120000  0.34120000
# 4  2026-08-30T00:04:00.000Z  TRXUSDT  binance  0.34120000  0.34120000
#
#           low       close      volume
# 0  0.34120000  0.34120000  0.00000000
# 1  0.34120000  0.34120000  0.00000000
# 2  0.34120000  0.34120000  0.00000000
# 3  0.34120000  0.34120000  0.00000000
# 4  0.34120000  0.34120000  0.00000000
