# %%
from achest import MarketDataClient
with MarketDataClient() as client:
    btc = client.get(["GDP"], "2026-01-01", "2026-01-31")

# %%
btc.head(5)
# Out:
#                   timestamp   symbol provider          open          high  \
# 0  2026-01-01T00:00:00.000Z  SOLUSDT  binance  124.96000000  128.25000000
# 1  2026-01-02T00:00:00.000Z  SOLUSDT  binance  127.47000000  133.15000000
# 2  2026-01-03T00:00:00.000Z  SOLUSDT  binance  132.26000000  133.93000000
# 3  2026-01-04T00:00:00.000Z  SOLUSDT  binance  133.46000000  135.39000000
# 4  2026-01-05T00:00:00.000Z  SOLUSDT  binance  134.17000000  139.71000000
#
#             low         close          volume
# 0  124.57000000  127.25000000  18807.34300000
# 1  126.32000000  132.25000000  21529.12600000
# 2  129.69000000  133.41000000   4429.76100000
# 3  133.17000000  134.01000000   4400.02000000
# 4  133.35000000  138.06000000   1803.09000000
