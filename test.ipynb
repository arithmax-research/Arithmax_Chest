# %%
from achest import MarketDataClient
from achest import beautify
import pandas as pd
client = MarketDataClient()

# %%
data = client.get(
    ["AAPL"],
    "2026-09-01",        # start (Sunday — won't matter)
    "2026-09-10",        # end = day AFTER last trading day you want
    "daily",
    provider="yahoo"
)
data.head(5)
# Out:
#                   timestamp symbol provider        open        high  \
# 0  2026-09-01T04:00:00.000Z   AAPL    yahoo  316.980011  327.299988
# 1  2026-09-02T04:00:00.000Z   AAPL    yahoo  326.869995  328.399994
# 2  2026-09-03T04:00:00.000Z   AAPL    yahoo  324.869995  330.809998
# 3  2026-09-04T04:00:00.000Z   AAPL    yahoo  328.309998  328.929993
# 4  2026-09-08T04:00:00.000Z   AAPL    yahoo  317.100006  320.700012
#
#           low       close    volume
# 0  314.730011  325.130005  53167400
# 1  323.529999  324.959991  33776400
# 2  324.109985  328.209991  37225800
# 3  317.859985  319.970001  39606900
# 4  314.899994  316.220001  35477100

# %%
df = beautify(client.news("AAPL"))        # nested → flattened table
df.head(5)
# Out:
#   related category                                           headline  \
# 0    AAPL  company  Apple’s New CEO Gets $55 Million, Then Takes t...
# 1    AAPL  company  Apple's Foldable iPhone Debuts Today: Will AAP...
# 2    AAPL  company  History Says September Is the Worst Month for ...
# 3    AAPL  company  Dow Jones Futures: Dow Breaks Support But AMD,...
# 4    AAPL  company  Prop Industry Leader The5ers Brings Single Sto...
#
#           id                                              image source  \
# 0  141961722  https://s.yimg.com/rz/stage/p/yahoo_finance_en...  Yahoo
# 1  141961091  https://s.yimg.com/rz/stage/p/yahoo_finance_en...  Yahoo
# 2  141961075  https://s.yimg.com/rz/stage/p/yahoo_finance_en...  Yahoo
# 3  141954985  https://s.yimg.com/rz/stage/p/yahoo_finance_en...  Yahoo
# 4  141954986  https://s.yimg.com/rz/stage/p/yahoo_finance_en...  Yahoo
#
#                                              summary  \
# 0  Apple's newest CEO walked into the top job wit...
# 1  Apple unveils its first foldable iPhone and iP...
# 2  It's usually not a good idea to bet against th...
# 3  Stocks fell Tuesday as oil prices and Treasury...
# 4  The5ers The5ers London, UK, Sept. 08, 2026 (GL...
#
#                                                  url    datetime  \
# 0  https://finnhub.io/api/news?id=f68d17d4cdd27ab...  1788918883
# 1  https://finnhub.io/api/news?id=e982b9b10637ca3...  1788917238
# 2  https://finnhub.io/api/news?id=f4771f8c6600d42...  1788915001
# 3  https://finnhub.io/api/news?id=47d7a5442d85da8...  1788903736
# 4  https://finnhub.io/api/news?id=ad5a14d387fd403...  1788902820
#
#                                              realUrl
# 0  https://finnhub.io/api/news?id=f68d17d4cdd27ab...
# 1  https://finnhub.io/api/news?id=e982b9b10637ca3...
# 2  https://finnhub.io/api/news?id=f4771f8c6600d42...
# 3  https://finnhub.io/api/news?id=47d7a5442d85da8...
# 4  https://finnhub.io/api/news?id=ad5a14d387fd403...

# %%
df = client.analyst("PLTR")
df.head(1)
# Out:
#        period  revenueEstimate  revenueHigh   revenueLow  revenueAnalysts  \
# 0  2030-12-31      70119130000  76428810000  64903418000                8
#
#    epsEstimate   epsHigh    epsLow  epsAnalysts  ebitEstimate     ebitHigh  \
# 0        14.38  16.06218  12.98947            3   46694236254  52156417381
#
#        ebitLow ebitAnalysts quarter  year
# 0  42179067410            8    None  2030

# %%
df = client.shipping_ports(search="Los Angeles")         # auto DF already
print(df)
# Out:
# []

# %%
df = client.crypto("fear-greed")
df.head(5)         # auto DF already
# Out:
#                        date  value classification
# 0  2026-09-09T22:00:00.000Z     69          Greed
# 1  2026-09-08T22:00:00.000Z     66          Greed
# 2  2026-09-07T22:00:00.000Z     69          Greed
# 3  2026-09-06T22:00:00.000Z     71          Greed
# 4  2026-09-05T22:00:00.000Z     73          Greed
