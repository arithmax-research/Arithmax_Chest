# %%
from achest import MarketDataClient
with MarketDataClient() as client:
    data = client.get(
        ["TRXUSDT"],          # list of ticker strings
        "2026-08-30",            # start date — see date formats below
        "2026-08-31",              # end date — see date formats below
        "second",
        "binance"      # bar size — see resolutions below
    )
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/anaconda3/envs/research_env/lib/python3.10/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/anaconda3/envs/research_env/lib/python3.10/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/anaconda3/envs/research_env/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
# ...

# %%
data.head(5)
# Out:
#                   timestamp   symbol provider        open        high  \
# 0  2026-04-16T11:00:00.000Z  TRXUSDT  binance  0.06697000  0.06697000
# 1  2026-04-16T11:01:00.000Z  TRXUSDT  binance  0.06697000  0.06697000
# 2  2026-04-16T11:02:00.000Z  TRXUSDT  binance  0.06697000  0.06697000
# 3  2026-04-16T11:03:00.000Z  TRXUSDT  binance  0.06697000  0.06697000
# 4  2026-04-16T11:04:00.000Z  TRXUSDT  binance  0.06697000  0.06697000
#
#           low       close      volume
# 0  0.06697000  0.06697000  0.00000000
# 1  0.06697000  0.06697000  0.00000000
# 2  0.06697000  0.06697000  0.00000000
# 3  0.06697000  0.06697000  0.00000000
# 4  0.06697000  0.06697000  0.00000000
