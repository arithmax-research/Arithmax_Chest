# %%
from achest import MarketDataClient
with MarketDataClient() as client:
    data = client.get(["GDP"], "2024-01-01", "2026-01-01")

# %%
gdp.head(5)
# Out:
#                   timestamp symbol provider       open       high        low  \
# 0  2024-01-01T00:00:00.000Z    GDP     fred  28708.161  28708.161  28708.161
# 1  2024-04-01T00:00:00.000Z    GDP     fred  29147.044  29147.044  29147.044
# 2  2024-07-01T00:00:00.000Z    GDP     fred  29511.664  29511.664  29511.664
# 3  2024-10-01T00:00:00.000Z    GDP     fred  29825.182  29825.182  29825.182
# 4  2025-01-01T00:00:00.000Z    GDP     fred  30042.113  30042.113  30042.113
#
#        close  volume
# 0  28708.161       0
# 1  29147.044       0
# 2  29511.664       0
# 3  29825.182       0
# 4  30042.113       0
